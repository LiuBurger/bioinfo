# %%
# add your source codes regarding the data fllow here

import matplotlib.pyplot as plt
import numpy as np

# %%
x_axis = np.arange(1,21)
loss1 = np.array([6.3892,2.9956,1.8023,1.2903,1.0167,0.8474,0.7319,0.6494,0.5859,0.5426,
                  0.5009,0.4747,0.4458,0.4270,0.4120,0.3980,0.3843,0.3700,0.3661,0.3543])
loss2 = np.array([4.1794,0.7659,0.3751,0.2857,0.2476,0.2374,0.1981,0.1963,0.1992,0.1775,
                  0.1672,0.1748,0.1711,0.1660,0.1539,0.1562,0.1440,0.1584,0.1515,0.1427])

plt.plot(x_axis, loss1, label='wrong method')
plt.plot(x_axis, loss2, label='correct method')

plt.xlabel('iterations')
plt.xticks(x_axis)
plt.ylabel('loss')
plt.title('Loss Plot')
plt.legend()
plt.show()

# %%
x_axis = np.arange(1,21)
acc1 = [37.84,62.65,72.70,77.92,80.93,82.79,84.44,85.85,86.38,86.75,
        87.46,88.17,88.46,88.28,88.99,88.91,88.69,89.31,88.54,89.34]
acc2 = [78.02,87.04,90.23,90.03,90.59,90.84,90.82,90.71,90.68,91.87,
        91.57,91.04,91.53,91.52,92.18,91.94,91.84,90.51,92.24,92.30]

plt.plot(x_axis, acc1, label='wrong method')
plt.plot(x_axis, acc2, label='correct method')

plt.xlabel('iterations')
plt.xticks(x_axis)
plt.ylabel('accuracy')
plt.title('Accuracy Plot')
plt.legend()
plt.show()
